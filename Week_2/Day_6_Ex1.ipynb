# %%
import numpy as np
import pandas as pd

idx_df = pd.read_csv("2.1b_excercise1_idxstats.tsv",sep="\t",header=None)

display(idx_df)
# Out:
#         0          1        2        3
# 0    chrM      16571      226        2
# 1    chr1  249250621  1202908    11586
# 2    chr2  243199373  1179409    11950
# 3    chr3  198022430   956939     7894
# 4    chr4  191154276   841065     8496
# 5    chr5  180915260   839376     7313
# 6    chr6  171115067   851357     6930
# 7    chr7  159138663   639203     7728
# 8    chr8  146364022   951606     8874
# 9    chr9  141213431   603020     6937
# 10  chr10  135534747   692429    10325
# 11  chr11  135006516   660885     7635
# 12  chr12  133851895   728753     6993
# 13  chr13  115169878   523741     4061
# 14  chr14  107349540   480831     4255
# 15  chr15  102531392   447954     3936
# 16  chr16   90354753   483073     5439
# 17  chr17   81195210   532624     5339
# 18  chr18   78077248   319957     4373
# 19  chr19   59128983   407712     5882
# 20  chr20   63025520   321007     3280
# 21  chr21   48129895   175650     2351
# 22  chr22   51304566   224761     2206
# ...

# %%
idx_df.columns = (['reference_sequence_name','sequence_length', 'number_mapped', 'number_unmapped'])

display(idx_df)
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped
# 0                     chrM            16571            226                2
# 1                     chr1        249250621        1202908            11586
# 2                     chr2        243199373        1179409            11950
# 3                     chr3        198022430         956939             7894
# 4                     chr4        191154276         841065             8496
# 5                     chr5        180915260         839376             7313
# 6                     chr6        171115067         851357             6930
# 7                     chr7        159138663         639203             7728
# 8                     chr8        146364022         951606             8874
# 9                     chr9        141213431         603020             6937
# 10                   chr10        135534747         692429            10325
# ...

# %%
idx_df.describe()
idx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   reference_sequence_name  26 non-null     object
#  1   sequence_length          26 non-null     int64
#  2   number_mapped            26 non-null     int64
#  3   number_unmapped          26 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 960.0+ bytes

# %%
idx_df.shape
idx_df.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
idx_df2 = idx_df.iloc[6:13,]

display(idx_df2)
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped
# 6                     chr6        171115067         851357             6930
# 7                     chr7        159138663         639203             7728
# 8                     chr8        146364022         951606             8874
# 9                     chr9        141213431         603020             6937
# 10                   chr10        135534747         692429            10325
# 11                   chr11        135006516         660885             7635
# 12                   chr12        133851895         728753             6993

# %%
chr_mapped = idx_df.iloc[[1,3],]
#save to tsv
display(chr_mapped)

chr_mapped.to_csv('mapped_reads_per_chr.tsv',sep='\t')
# Out:
#   reference_sequence_name  sequence_length  number_mapped  number_unmapped
# 1                    chr1        249250621        1202908            11586
# 3                    chr3        198022430         956939             7894

# %%
idx_df["reads_per_base"]=idx_df['number_mapped']/idx_df['sequence_length']
display(idx_df)
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped  \
# 0                     chrM            16571            226                2
# 1                     chr1        249250621        1202908            11586
# 2                     chr2        243199373        1179409            11950
# 3                     chr3        198022430         956939             7894
# 4                     chr4        191154276         841065             8496
# 5                     chr5        180915260         839376             7313
# 6                     chr6        171115067         851357             6930
# 7                     chr7        159138663         639203             7728
# 8                     chr8        146364022         951606             8874
# 9                     chr9        141213431         603020             6937
# 10                   chr10        135534747         692429            10325
# ...

# %%
mask = idx_df['reads_per_base'] > 0.005
mask.to_frame()
idx_df2 = idx_df[mask]
display(idx_df2)
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped  \
# 0                     chrM            16571            226                2
# 8                     chr8        146364022         951606             8874
# 10                   chr10        135534747         692429            10325
# 12                   chr12        133851895         728753             6993
# 16                   chr16         90354753         483073             5439
# 17                   chr17         81195210         532624             5339
# 19                   chr19         59128983         407712             5882
# 20                   chr20         63025520         321007             3280
#
#     reads_per_base
# 0         0.013638
# 8         0.006502
# 10        0.005109
# 12        0.005444
# 16        0.005346
# 17        0.006560
# 19        0.006895
# 20        0.005093

# %%
idx_df['length_Mbs']=idx_df['sequence_length']/1000000
display(idx_df)
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped  \
# 0                     chrM            16571            226                2
# 1                     chr1        249250621        1202908            11586
# 2                     chr2        243199373        1179409            11950
# 3                     chr3        198022430         956939             7894
# 4                     chr4        191154276         841065             8496
# 5                     chr5        180915260         839376             7313
# 6                     chr6        171115067         851357             6930
# 7                     chr7        159138663         639203             7728
# 8                     chr8        146364022         951606             8874
# 9                     chr9        141213431         603020             6937
# 10                   chr10        135534747         692429            10325
# ...

# %%
mask2 = (idx_df['reads_per_base'] > 0.005) & (idx_df['length_Mbs'] < 100)
mask2.to_frame()
idx_df3 = idx_df[mask2]
idx_df3
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped  \
# 0                     chrM            16571            226                2
# 16                   chr16         90354753         483073             5439
# 17                   chr17         81195210         532624             5339
# 19                   chr19         59128983         407712             5882
# 20                   chr20         63025520         321007             3280
#
#     reads_per_base  length_Mbs
# 0         0.013638    0.016571
# 16        0.005346   90.354753
# 17        0.006560   81.195210
# 19        0.006895   59.128983
# 20        0.005093   63.025520

# %%
idx_df5=idx_df.drop('reads_per_base',axis=1)
idx_df5
# Out:
#    reference_sequence_name  sequence_length  number_mapped  number_unmapped  \
# 0                     chrM            16571            226                2
# 1                     chr1        249250621        1202908            11586
# 2                     chr2        243199373        1179409            11950
# 3                     chr3        198022430         956939             7894
# 4                     chr4        191154276         841065             8496
# 5                     chr5        180915260         839376             7313
# 6                     chr6        171115067         851357             6930
# 7                     chr7        159138663         639203             7728
# 8                     chr8        146364022         951606             8874
# 9                     chr9        141213431         603020             6937
# 10                   chr10        135534747         692429            10325
# ...
